# %%
import pandas as pd
import numpy as np
final_articles = pd.read_csv("data/final-articles.csv")

# %%
STANDARD_COLUMNS = [
    "title",
    "content",
    "author",
    "publish_time",
    "link",
    "source"
]

# %%
# standardizing column names
final_articles = final_articles.rename(columns={"publish-time": "publish_time"})

# %%
final_articles["content"].str.split().str.len().describe()
# Out:
# count    11960.000000
# mean       573.469900
# std        547.445568
# min          0.000000
# 25%        253.000000
# 50%        383.000000
# 75%        697.000000
# max       5597.000000
# Name: content, dtype: float64

# %%
print(final_articles.columns)
# Out:
# Index(['link', 'author', 'title', 'content', 'publish_time', 'source'], dtype='str')
